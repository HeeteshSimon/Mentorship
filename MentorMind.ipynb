# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("MentorMind-Project-DATA - Sheet2.csv")

# %%
df.head()
# Out:
#    1  A1 A1.1 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0  2  A1   A1         A1         A1         A1         A1         A1
# 1  3  A2   A2         A2         A1         A3         A1        NaN
# 2  4  A1   A1         A1         A1         A1         A1        NaN
# 3  5  A1   A1         A1         A4         A5         A3         A4
# 4  6  A1   A7         A7         A2         A8         A1        NaN
#
#   Unnamed: 8 Unnamed: 9  ... Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15  \
# 0        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 1        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 2        NaN        NaN  ...         NaN         NaN         NaN         NaN
# 3         A5         A6  ...          A8          A9         A10          A1
# 4        NaN        NaN  ...         NaN         NaN         NaN         NaN
#
#   Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 22 columns]

# %%
df.set_index(df.columns[0],inplace=True)

# %%
df.head()
# Out:
#    A1.1 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# A1
# A1   A1         A1         A1         A1         A1         A1        NaN
# A2   A2         A2         A1         A3         A1        NaN        NaN
# A1   A1         A1         A1         A1         A1        NaN        NaN
# A1   A1         A1         A4         A5         A3         A4         A5
# A1   A7         A7         A2         A8         A1        NaN        NaN
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# A1
# A1        NaN         NaN         NaN         NaN         NaN         NaN
# A2        NaN         NaN         NaN         NaN         NaN         NaN
# A1        NaN         NaN         NaN         NaN         NaN         NaN
# A1         A6          A7          A2          A8          A9         A10
# A1        NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# A1
# A1         NaN         NaN         NaN         NaN         NaN         NaN
# A2         NaN         NaN         NaN         NaN         NaN         NaN
# A1         NaN         NaN         NaN         NaN         NaN         NaN
# A1          A1         NaN         NaN         NaN         NaN         NaN
# A1         NaN         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 21
# A1
# A1         NaN
# A2         NaN
# A1         NaN
# A1         NaN
# A1         NaN

# %%
data=[]
for i in range(100):
    x=df.values[i]
    x=x[~pd.isnull(x)]
    data.append(x)
data
# Out:
# [array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A2', 'A2', 'A1', 'A3', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A1', 'A1', 'A4', 'A5', 'A3', 'A4', 'A5', 'A6', 'A7', 'A2', 'A8',
#         'A9', 'A10', 'A1'], dtype=object),
#  array(['A7', 'A7', 'A2', 'A8', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A4', 'A5', 'A6', 'A7', 'A2', 'A8', 'A9', 'A10', 'A1', 'A1'],
#        dtype=object),
#  array(['A7', 'A2', 'A2', 'A2', 'A2', 'A8', 'A10', 'A10', 'A10', 'A10',
#         'A10', 'A10', 'A10', 'A10', 'A10', 'A10', 'A10', 'A1'],
#        dtype=object),
#  array(['A1', 'A10', 'A10', 'A10', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A8', 'A8', 'A8', 'A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A2', 'A8', 'A9', 'A10', 'A7', 'A8', 'A8', 'A2', 'A1', 'A1'],
#        dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array(['A7', 'A7', 'A2', 'A2', 'A2', 'A1', 'A5', 'A1', 'A1'], dtype=object),
#  array([], dtype=object),
#  array(['A1'], dtype=object),
#  array([], dtype=object),
#  array(['A10', 'A1'], dtype=object),
#  array([], dtype=object),
#  array(['A3', 'A6', 'A7', 'A2', 'A8', 'A9', 'A10', 'A1'], dtype=object),
#  array(['A11', 'A1', 'A1', 'A1'], dtype=object),
#  array(['A10', 'A10', 'A1'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A2', 'A8', 'A1'], dtype=object),
#  array(['A8', 'A7', 'A5', 'A7', 'A8', 'A8', 'A1'], dtype=object),
#  array([], dtype=object),
#  array(['A1'], dtype=object),
#  array([], dtype=object),
#  array(['A1', 'A4', 'A4', 'A7', 'A7', 'A7', 'A7', 'A7', 'A7', 'A2', 'A1'],
#        dtype=object),
#  array(['A3', 'A4', 'A5', 'A7', 'A2', 'A9', 'A10', 'A1'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A8', 'A8', 'A8', 'A8', 'A10', 'A10', 'A1'], dtype=object),
#  array([], dtype=object),
#  array(['A9', 'A10', 'A9', 'A3', 'A1'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A3', 'A3', 'A6', 'A5', 'A6', 'A7', 'A2', 'A9', 'A10', 'A1'],
#        dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A10', 'A10', 'A10', 'A1'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A1'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A1'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A2', 'A2', 'A1'], dtype=object),
#  array(['A2', 'A8', 'A9', 'A10', 'A1'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A1'], dtype=object),
#  array(['A8', 'A8', 'A10', 'A10', 'A10', 'A10', 'A10', 'A10', 'A10', 'A1',
#         'A1', 'A1'], dtype=object),
#  array([], dtype=object),
#  array(['A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A7', 'A1'],
#        dtype=object),
#  array(['A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2', 'A2',
#         'A2', 'A1'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A1'], dtype=object),
#  array([], dtype=object),
#  array(['A8', 'A8', 'A8', 'A8', 'A8', 'A8', 'A2', 'A1'], dtype=object),
#  array(['A1', 'A1'], dtype=object),
#  array([], dtype=object),
#  array(['A10', 'A10', 'A1'], dtype=object),
#  array([], dtype=object),
#  array(['A1', 'A7', 'A5', 'A7', 'A7', 'A1'], dtype=object),
#  array([], dtype=object),
#  array(['A8', 'A9', 'A2', 'A10', 'A4', 'A5', 'A6', 'A4', 'A1', 'A1'],
#        dtype=object),
#  array(['A10', 'A1'], dtype=object),
#  array([], dtype=object),
#  array(['A7', 'A2', 'A8', 'A3', 'A3', 'A3', 'A3', 'A3', 'A3', 'A3', 'A5',
#         'A4', 'A5', 'A6', 'A7', 'A2', 'A8', 'A9', 'A10', 'A1'],
#        dtype=object),
#  array([], dtype=object),
#  array(['A9', 'A4', 'A5', 'A5', 'A3', 'A4', 'A4', 'A7', 'A7', 'A7', 'A7',
#         'A7', 'A2', 'A8', 'A1'], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array([], dtype=object),
#  array(['A4', 'A5', 'A6', 'A7', 'A2', 'A8', 'A9', 'A10', 'A1'],
#        dtype=object),
#  array(['A4', 'A5', 'A6', 'A7', 'A2', 'A8', 'A9', 'A10', 'A1'],
#        dtype=object),
#  array(['A1', 'A1', 'A1', 'A1', 'A1', 'A1'], dtype=object)]

# %%
from markovclick.models import MarkovClickstream
m = MarkovClickstream(data)

# %%
fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
sns.heatmap(m.prob_matrix, xticklabels=m.pages, yticklabels=m.pages,cmap="YlGnBu")

# %%
    from markovclick.viz import visualise_markov_chain
    graph = visualise_markov_chain(m)

# %%
print(graph.source)
# Out:
# digraph {
# 	A1 [label=A1 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A1 -> A1 [label=0.82 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A1 -> A4 [label="   0.06" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A10 [label=A10 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A10 -> A10 [label=0.52 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A10 -> A1 [label="   0.41" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A11 [label=A11 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A11 -> A1 [label=1.00 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A11 -> A9 [label="   0.00" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A11 -> A11 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A2 [label=A2 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A2 -> A2 [label=0.52 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A2 -> A8 [label="   0.26" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A3 [label=A3 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A3 -> A3 [label=0.47 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A3 -> A4 [label="   0.20" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A4 [label=A4 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A4 -> A5 [label=0.64 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A4 -> A7 [label="   0.14" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A4 -> A4 [label="   0.14" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A5 [label=A5 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A5 -> A6 [label=0.47 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A5 -> A7 [label="   0.20" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A5 -> A5 [label="   0.07" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A6 [label=A6 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A6 -> A7 [label=0.78 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A6 -> A5 [label="   0.11" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A6 -> A6 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# 	A7 [label=A7 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A7 -> A7 [label=0.45 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A7 -> A2 [label="   0.39" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A8 [label=A8 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A8 -> A8 [label=0.38 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A8 -> A9 [label="   0.26" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A9 [label=A9 fillcolor="#76ff03" fontcolor="#1a237e" fontname=Helvetica penwidth=0 style=filled]
# 	A9 -> A10 [label=0.79 arrowsize=0.75 color="#90caf9" fontname=Helvetica penwidth=1.5]
# 	A9 -> A4 [label="   0.07" arrowsize=0.5 color="#90caf9" fontname=Helvetica fontsize=10 penwidth=0.75]
# 	A9 -> A9 [label="   0.00" arrowsize=0.5 color="#cfd8dc" fontname=Helvetica fontsize=10 penwidth=1.8]
# }

# %%
import os
os.environ["PATH"] += os.pathsep + r'C:\Users\Heetesh\anaconda3\Library\bin\graphviz'
graph.render('test-output/round-table.gv', view=True)
# Out:
# 'test-output\\round-table.gv.pdf'

# %%
graph
